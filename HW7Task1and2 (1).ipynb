# %% [markdown]
# ## HW7

# %% [markdown]
# ### Task 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline, PchipInterpolator
# %matplotlib inline

# %%
#загрузим файл и извлечём два вектора с координатами
data = np.load('data.npz')
x1 = data['x1']
y1 = data['y1']

# %%
#посмотрим на заданную функцию
plt.scatter(x1, y1)

# %%
#похоже на смещённую функцию Хевисайда

# %%
#интерполяционный Лагранжев многочлен

# %%
#рассчитываем один полином
def lagrange(x, x1, k):
    n = len(x1)
    num = 1.0
    den = 1.0
    for j in range(n):
        if j == k:
            continue
        den *= x1[k] - x1[j]
        num *= x - x1[j]
    return num/den

# %%
lagrange(x1[0], x1, 1)
# Out:
# 0.0

# %%
#теперь все 
def interp(x, x1, y1):
    return sum([lagrange(x, x1, i) * y1[i] for i in range(len(x1))])

# %%
#построим функцию
xs = np.linspace(0, 10000, 1000)
ys = [interp(k, x1, y1) for k in xs]
plt.plot(xs, ys)
plt.scatter(x1, y1)

# %%
#как видим, наша подгонка под конец сильно убывает, да так, что из-за масштаба верхняя и нижняя линии исходной функции
#слились в одну
#рассмотрим отдельно место излома
plt.xlim(3000, 7000)
plt.ylim(-1.5, 0.5)
plt.plot(xs, ys)
plt.scatter(x1, y1)

# %%
#как видим, проблема не только в масштабе, функция начинает себя очень странно вести, когда попадает на верхние точки

# %%
#попробуем другие способы

# %%
#Кубический сплайн

# %%
cubic = CubicSpline(x1, y1)
plt.plot(xs, cubic(xs))
plt.scatter(x1, y1)

# %%
#Монотонный кубический интерполянт

# %%
cubic = PchipInterpolator(x1, y1)
plt.plot(xs, cubic(xs))
plt.scatter(x1, y1)

# %% [markdown]
# ### Task 2

# %%
#polyfit
def plotpolyfit(n):
    x = np.linspace(-1, 1, n)
    y = np.cos(n * x)
    plt.scatter(x, y)
    z = np.polyfit(x, y, n)
    ypol = np.poly1d(z)
    xs = np.linspace(-1, 1, 1000)
    plt.plot(xs, ypol(xs))

# %%
n = 16
plotpolyfit(n)
# Out:
# c:\users\alyva\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: RankWarning: Polyfit may be poorly conditioned

# %%
n = 32
plotpolyfit(n)
# Out:
# c:\users\alyva\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: RankWarning: Polyfit may be poorly conditioned

# %%
n = 64
plotpolyfit(n)
# Out:
# c:\users\alyva\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: RankWarning: Polyfit may be poorly conditioned

# %%
#теперь попробуем Лагранжем

# %%
n = 16
x = np.linspace(-1, 1, n)
y = np.cos(n * x)
xs = np.linspace(-1, 1, 1000)
ys = [interp(k, x, y) for k in xs]
plt.plot(xs, ys)
plt.scatter(x, y)

# %%
#попробуем взять большу плотность точек на краях
n = 16
x = np.linspace(-1, 1, n)
y = np.cos(n * x)
xs = [np.cos(j * np.pi / (100 * n)) for j in range(100 * n)]
ys = [interp(k, x, y) for k in xs]
plt.plot(xs, ys)
plt.scatter(x, y)

# %%
#не помогло

# %%
#оба способа ломаются на краях

# %%
#посмотрим как ведёт себя подгонка не на краях

# %%
plt.ylim(-1, 1)
plotpolyfit(16)
# Out:
# c:\users\alyva\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: RankWarning: Polyfit may be poorly conditioned

# %%
plt.ylim(-1, 1)
plotpolyfit(32)
# Out:
# c:\users\alyva\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: RankWarning: Polyfit may be poorly conditioned

# %%
plt.ylim(-1, 1)
plotpolyfit(64)
# Out:
# c:\users\alyva\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: RankWarning: Polyfit may be poorly conditioned

# %%
#как видим, при n=64 подгонка начала вести себя странно и не проходит через все точки

# %%
#то же самое сделаем для Лагранжа
def lagrange2(n):
    x = np.linspace(-1, 1, n)
    y = np.cos(n * x)
    xs = np.linspace(-1, 1, 1000)
    ys = [interp(k, x, y) for k in xs]
    plt.plot(xs, ys)
    plt.scatter(x, y)

# %%
plt.ylim(-1, 1)
lagrange2(16)

# %%
plt.ylim(-1, 1)
lagrange2(32)

# %%
plt.ylim(-1, 1)
lagrange2(64)

# %%
#как видим для этого способа не возникает странности, которую мы заметили для полифита
#Лагранжева интерполяция проходит через все точки, чего и следовало ожидать, так как она именно так и строится
